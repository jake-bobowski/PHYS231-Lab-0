# %%
import installer
installer.Check()
# Out:
# <text style=color:black>All packages already installed. Please proceed.</text>

# %%
# Import required and commonly-used modules
import numpy as np
import matplotlib.pyplot as plt
import httpimport
import uncertainties
import ipysheet
with httpimport.remote_repo(['data_entry'], 'https://cmps-people.ok.ubc.ca/jbobowsk/phys231/Python'):
    import data_entry
with httpimport.remote_repo(['PHYS231'], 'https://cmps-people.ok.ubc.ca/jbobowsk/phys231/Python'):
    import PHYS231

# %%
PHYS231.Spreadsheet('Lab0_data')
# Out:
# Sheet name: Lab0_data.csv
# ...

# %%
fig1 = PHYS231.Scatter(v_t, v_y, v_erry)

# %%
fig2 = PHYS231.LinearFit(v_t, v_y, v_erry)
# Out:
# $y = m\,x + b$
# This is a **WEIGHTED** fit.
#                               Value
# slope          $m =$  1.965+/-0.057
# $y$-intercept  $b =$    4.23+/-0.15
